# %% [markdown]
# ## Importamos las librerias Necesarias.

# %%
import mysql.connector
import pandas as pd
import streamlit as st
from sqlalchemy import create_engine

# %% [markdown]
# ## Conexión a la DB

# %%
# Parámetros de conexión
user = "coniitic_registro"
password = "G3!+GUyN-1bXP+]x"
host = "coniiti.com"
database = "coniitic_registro"

engine = create_engine(
    f"mysql+pymysql://{user}:{password}@{host}/{database}"
)

# Consulta (cambia el nombre si tu tabla no se llama regeventos)
query = "SELECT * FROM regeventos"

df = pd.read_sql(query, engine)

df.head()
# Out:
#    id           qr_Acceso         nombres        apellidos  \
# 0   4  OXL3IHNL6KFN8KGPQE           yenny        hernandez
# 1   5  5RBN17AAE2OOL47485  Diego Fernando  Meléndez Suárez
# 2   6  R2SV7WXIAQ63Y1GIL3  Diego Fernando  Meléndez Suárez
# 3   7  P58X4OTXBNFUAQIJ54  Diego Fernando  Meléndez Suárez
# 4   8  MK8DW21CHVHXTGBAS5      Oscar Raul      Pinto Celis
#
#                           email    telefono tipo_documento num_documento  \
# 0  jphernandez@ucatolica.edu.co  3168232187             CC    1024486270
# 1   dfmelendez@ucatolica.edu.co  3183530817             CC      91284150
# 2   dfmelendez@ucatolica.edu.co  3183530817             CC      91284150
# 3   dfmelendez@ucatolica.edu.co  3183530817             CC      91284150
# 4      orpinto@ucatolica.edu.co  3125812914             CC      91500261
#
#       genero      pais ucatolica                      rol  \
# 0   Femenino  Colombia         S           Administrativo
# 1  Masculino  Colombia         S  Profesor/Administrativo
# 2  Masculino  Colombia         S  Profesor/Administrativo
# 3  Masculino  Colombia         S  Profesor/Administrativo
# 4  Masculino  Colombia         S  Profesor/Administrativo
#
#                            programa                  profesion  \
# 0            Facultad de Ingeniería  Adminsitradora financiera
# 1  Esp. en Ingeniería de Pavimentos            Ingeniero Civil
# 2  Esp. en Ingeniería de Pavimentos            Ingeniero Civil
# 3  Esp. en Ingeniería de Pavimentos            Ingeniero Civil
# 4         Esp. en Gerencia de Obras            Ingeniero Civil
#
#                                           nom_Evento  qr_validado  \
# 0  Del reto a la solución: Innovar con Design Thi...            1
# 1  Workshop: Diseños de mezcla de concreto bajo l...            0
# 2  Conferencia : Arquitectura y diseño sostenible...            0
# 3  Conferencia: Proyectos comprometidos con la so...            0
# 4  Conferencia: Premio Nacional de Ingeniería: Re...            1
#
#             fecha_uso      fecha_registro
# 0 2025-10-01 15:05:30 2025-09-30 13:58:57
# 1                 NaT 2025-09-30 18:15:53
# 2                 NaT 2025-09-30 18:31:52
# 3                 NaT 2025-09-30 18:32:43
# 4 2025-10-02 14:05:02 2025-09-30 18:32:53

# %%
st.title("Dashboard CONIITI 2025")
st.metric("Tasa de asistencia", "78%")
# Out:
# 2026-03-19 02:46:43.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-19 02:46:43.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-19 02:46:43.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-19 02:46:43.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-19 02:46:43.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-19 02:46:43.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
